# %%
import pandas as pd
import numpy as np
import json

# %%
with open('../../data/batdongsan/ChungCu_raw-dataset.json','r',encoding='utf-8') as file:
    data = json.load(file)
df_raw = pd.json_normalize(data)
df_raw.drop_duplicates(inplace=True)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22827 entries, 0 to 38636
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DienTich      22823 non-null  object
#  1   DiaChi        22826 non-null  object
#  2   City          22826 non-null  object
#  3   District      22826 non-null  object
#  4   MucGia        22826 non-null  object
#  5   SoPhongNgu    22232 non-null  object
#  6   SoToilet      21078 non-null  object
#  7   NoiThat       17514 non-null  object
#  8   Lat           22793 non-null  float64
#  9   Long          22793 non-null  float64
#  10  HuongNha      9178 non-null   object
#  11  HuongBanCong  10070 non-null  object
#  12  PhapLy        18335 non-null  object
#  13  MatTien       20 non-null     object
#  14  DuongVao      19 non-null     object
#  15  SoTang        21 non-null     object
# dtypes: float64(2), object(14)
# memory usage: 3.0+ MB

# %%
df_raw.drop(columns=['HuongNha','HuongBanCong','NoiThat','SoPhongNgu','SoTang','SoToilet'])
# Out:
#         DienTich                                             DiaChi  \
# 0         180 m²         Đường 768, Xã Tân Bình, Vĩnh Cửu, Đồng Nai
# 1      29.235 m²  Hẻm 50, Đường 1/5, Phường B'Lao, Bảo Lộc, Lâm ...
# 2         250 m²               Phường Cô Giang, Quận 1, Hồ Chí Minh
# 3          63 m²  Đường Bạch Thái Bưởi, Phường Đằng Giang, Ngô Q...
# 4       3.000 m²                         Xã Cẩm Lĩnh, Ba Vì, Hà Nội
# ...          ...                                                ...
# 40038     340 m²  Đường Quốc Lộ 3, Phường Đề Thám, Cao Bằng, Cao...
# 40039     100 m²  Đường Quốc lộ 37, Phường Sông Hiến, Cao Bằng, ...
# 40040      72 m²                Phường Đề Thám, Cao Bằng, Cao Bằng.
# 40041     300 m²                 Phường Đề Thám, Cao Bằng, Cao Bằng
# 40042   1.270 m²                 Phường Đề Thám, Cao Bằng, Cao Bằng
#
#               City   District        MucGia MatTien DuongVao           PhapLy  \
# ...

# %%
df_raw['HuongNha'].unique().tolist()
# Out:
# [nan,
#  'Đông - Nam',
#  'Tây - Nam',
#  'Đông',
#  'Bắc',
#  'Nam',
#  'Đông - Bắc',
#  'Tây',
#  'Tây - Bắc']
