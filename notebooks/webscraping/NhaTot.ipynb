# %% [markdown]
# # Cài đặt các thư viện cần thiết để cào dữ liệu

# %%
# %pip install pandas numpy beautifulsoup4 selenium cloudscraper selenium unidecode
# Out:
# Requirement already satisfied: pandas in d:\app\code\anaconda\anaconda3\envs\sic_bigdata_env\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in d:\app\code\anaconda\anaconda3\envs\sic_bigdata_env\lib\site-packages (2.0.0)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting selenium
#   Using cached selenium-4.22.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting cloudscraper
#   Using cached cloudscraper-1.2.71-py2.py3-none-any.whl.metadata (19 kB)
# Collecting unidecode
#   Using cached Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\app\code\anaconda\anaconda3\envs\sic_bigdata_env\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in d:\app\code\anaconda\anaconda3\envs\sic_bigdata_env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\app\code\anaconda\anaconda3\envs\sic_bigdata_env\lib\site-packages (from pandas) (2024.1)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting urllib3<3,>=1.26 (from urllib3[socks]<3,>=1.26->selenium)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting trio~=0.17 (from selenium)
#   Using cached trio-0.25.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Using cached trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting certifi>=2021.10.8 (from selenium)
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: typing_extensions>=4.9.0 in d:\app\code\anaconda\anaconda3\envs\sic_bigdata_env\lib\site-packages (from selenium) (4.12.2)
# Collecting websocket-client>=1.8.0 (from selenium)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting pyparsing>=2.4.7 (from cloudscraper)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting requests>=2.9.2 (from cloudscraper)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-toolbelt>=0.9.1 (from cloudscraper)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: six>=1.5 in d:\app\code\anaconda\anaconda3\envs\sic_bigdata_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.9.2->cloudscraper)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.9.2->cloudscraper)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting outcome (from trio~=0.17->selenium)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting cffi>=1.14 (from trio~=0.17->selenium)
#   Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl.metadata (1.5 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting pycparser (from cffi>=1.14->trio~=0.17->selenium)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached selenium-4.22.0-py3-none-any.whl (9.4 MB)
# Using cached cloudscraper-1.2.71-py2.py3-none-any.whl (99 kB)
# Using cached Unidecode-1.3.8-py3-none-any.whl (235 kB)
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Using cached trio-0.25.1-py3-none-any.whl (467 kB)
# Using cached trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.5 kB ? eta -:--:--
#    -------- ------------------------------ 41.0/181.5 kB 991.0 kB/s eta 0:00:01
#    -------------------------------------- - 174.1/181.5 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 181.5/181.5 kB 1.8 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.9 kB ? eta -:--:--
#    ---------------------------------------- 99.9/99.9 kB 5.6 MB/s eta 0:00:00
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: sortedcontainers, websocket-client, urllib3, unidecode, soupsieve, sniffio, pysocks, pyparsing, pycparser, idna, h11, charset-normalizer, certifi, attrs, wsproto, requests, outcome, cffi, beautifulsoup4, trio, requests-toolbelt, trio-websocket, cloudscraper, selenium
# Successfully installed attrs-23.2.0 beautifulsoup4-4.12.3 certifi-2024.6.2 cffi-1.16.0 charset-normalizer-3.3.2 cloudscraper-1.2.71 h11-0.14.0 idna-3.7 outcome-1.3.0.post0 pycparser-2.22 pyparsing-3.1.2 pysocks-1.7.1 requests-2.32.3 requests-toolbelt-1.0.0 selenium-4.22.0 sniffio-1.3.1 sortedcontainers-2.4.0 soupsieve-2.5 trio-0.25.1 trio-websocket-0.11.1 unidecode-1.3.8 urllib3-2.2.2 websocket-client-1.8.0 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
from unidecode import unidecode
import json
import cloudscraper

# %% [markdown]
# # Cấu hình cho trình duyệt để cào dữ liệu

# %%
# Đường dẫn tới ChromeDriver
# chromedriver_path = "D:/APP/chromedriver/chromedriver.exe"

# Cấu hình ChromeDriver service
# service = webdriver.ChromeService(chromedriver_path)

options = webdriver.ChromeOptions()

# Cấu hình để web không cần load hình ảnh và javascript
chrome_prefs = {
    "profile.default_content_setting_values": {
        "images": 2,
    }
}
options.experimental_options["prefs"] = chrome_prefs
# Chạy ẩn danh (không hiển thị trình duyệt)
options.add_argument("--headless=new")
# Một số hệ thống check user-agent và không cho headless-chrome chạy nên phải thêm user-agent
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
options.add_argument("--disable-gpu")  # Tắt GPU (không cần thiết cho chế độ headless)
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument('--disable-notifications')

# %% [markdown]
# # Cào link

# %%
try:
    baseUrl = "https://www.nhatot.com/mua-ban-can-ho-chung-cu?page="
    linkSelector = "a.AdItem_adItem__gDDQT"
    # Danh sách để lưu trữ các link
    arr = []

    # Lặp qua các trang
    for pageNum in range(1,5):
        driver = webdriver.Chrome(options=options)
        # Mở trang web
        url = baseUrl + str(pageNum)
        print(f"Đang lấy dữ liệu từ trang: {url}")
        driver.get(url)
        
        # Lấy tất cả các đường link sản phẩm
        links = driver.find_elements(By.CSS_SELECTOR, linkSelector)
        
        for link in links:
            arr.append(link.get_attribute('href'))
        driver.close()
        driver.quit()
except Exception as e:
    print(f"Có lỗi xảy ra: {str(e)}")

# Tạo DataFrame từ danh sách các link
df = pd.DataFrame(arr, columns=['links'])
print("Hoàn thành lấy dữ liệu!")
# Out:
# Đang lấy dữ liệu từ trang: https://www.nhatot.com/mua-ban-can-ho-chung-cu?page=1
# Đang lấy dữ liệu từ trang: https://www.nhatot.com/mua-ban-can-ho-chung-cu?page=2
# Đang lấy dữ liệu từ trang: https://www.nhatot.com/mua-ban-can-ho-chung-cu?page=3
# Đang lấy dữ liệu từ trang: https://www.nhatot.com/mua-ban-can-ho-chung-cu?page=4
# Hoàn thành lấy dữ liệu!

# %%
try:
    baseUrl = "https://www.nhatot.com/mua-ban-can-ho-chung-cu?page="
    linkSelector = "a.AdItem_adItem__gDDQT"
    scraper = cloudscraper.create_scraper(delay = 10, browser={'browser': 'chrome','platform': 'windows','mobile': False})
    # Danh sách để lưu trữ các link
    arr = []

    # Lặp qua các trang
    for pageNum in range(1,5):
        url = baseUrl + str(pageNum)
        response = scraper.get(url)
        print(f"Đang lấy dữ liệu từ trang: {url} - {response.status_code}")
        time.sleep(5)
        soup = BeautifulSoup(response.text, 'html.parser')
        # Lấy tất cả các thẻ <a>
        links = soup.select(linkSelector)
        
        for link in links:
            arr.append('https://www.nhatot.com/' + link.attrs['href'])
except Exception as e:
    print(f"Có lỗi xảy ra: {str(e)}")

# Tạo DataFrame từ danh sách các link
df = pd.DataFrame(arr, columns=['links'])
print("Hoàn thành lấy dữ liệu!")
# Out:
# Đang lấy dữ liệu từ trang: https://www.nhatot.com/mua-ban-can-ho-chung-cu?page=1 - 403
# Đang lấy dữ liệu từ trang: https://www.nhatot.com/mua-ban-can-ho-chung-cu?page=2 - 403
# Đang lấy dữ liệu từ trang: https://www.nhatot.com/mua-ban-can-ho-chung-cu?page=3 - 403
# Đang lấy dữ liệu từ trang: https://www.nhatot.com/mua-ban-can-ho-chung-cu?page=4 - 403
# Hoàn thành lấy dữ liệu!

# %% [markdown]
# ## Xuất file links

# %%
df.to_csv('../../data/test/chotot_links.csv', index=False)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [links]
# Index: []

# %% [markdown]
# # Test thử xem lấy được dữ liệu không

# %%
df_links = pd.read_csv('../../data/test/chotot_links.csv')
df_links.shape
# Out:
# (87, 1)

# %% [markdown]
# # Cào dữ liệu

# %%
def getdata(link:str) -> dict:
    # Tạo instance của trình điều khiển Chrome
    driver = webdriver.Chrome(options=options)
    driver.start_session()
    # Mở trang web        
    driver.get(link)

    # Đóng trình duyệt nếu trang đã bị xóa
    try:
        driver.find_element(By.CSS_SELECTOR, '.fz13')
    except: return
    
    # Bấm vào modal để tắt nó
    try:
        driver.find_element(By.CSS_SELECTOR, '.aw__s1cdo2zu').click()
    except: pass

    # Bấm nút 'Xem thêm' nếu có
    try:
        driver.find_element(By.CSS_SELECTOR, 'button.styles_button__SVZnw').click()
        # Đợi để load nội dung
        time.sleep(1)
    except: pass
    
    # Lấy nội dung HTML của trang
    html_text = driver.page_source
    driver.close()
    driver.quit()

    # Phân tích HTML để trích xuất dữ liệu
    soup = BeautifulSoup(html_text,'html.parser')
    item = {
        'DiaChi': soup.find('span',class_ = 'fz13').text.replace('Xem bản đồ','')
    }
    # Chọn bảng chứa thuộc tính để lấy dữ liệu
    attrTable = soup.find('div', class_ = 'AdParam_adParamContainerVeh__Vz4Zt')
    # Lấy tất cả các thuộc tính
    attrStrings = [ele.text for ele in attrTable.select('.media-body.media-middle')]
    # Tách chuỗi và gán key-value cho item
    for attrString in attrStrings:
        key, val = attrString.split(':')
        # Chuyển key thành không dấu và PascalCase
        item[unidecode(key.title().replace(' ',''))] = val.strip()
    return item

# %%
getdata('https://www.nhatot.com/mua-ban-nha-dat-huyen-can-giuoc-long-an/117455977.htm#px=SR-stickyad-[PO-1][PL-top]')
# Out:
# {'DiaChi': 'Tân Kim, Xã Tân Kim, Huyện Cần Giuộc, Long An',
#  'DienTichDat': '40 m²',
#  'Gia/M2': '18,5 triệu/m²',
#  'SoPhongNgu': '2 phòng',
#  'SoPhongVeSinh': '2 phòng',
#  'TongSoTang': '1',
#  'GiayToPhapLy': 'Đã có sổ',
#  'LoaiHinhNhaO': 'Nhà ngõ, hẻm',
#  'TinhTrangNoiThat': 'Nội thất đầy đủ',
#  'ChieuNgang': '4 m',
#  'ChieuDai': '10 m',
#  'DienTichSuDung': '80 m²',
#  'DacDiemNha/Dat': 'Hẻm xe hơi'}

# %% [markdown]
# ## Cào và lưu ra file json

# %%
with open('../../data/test/res.json', 'w') as file:
    file.write('[') # Bắt đầu một json array
    first = True

    for link in df_links['links']:
        print(link)
        data = getdata(link)
        if data is not None:
            if not first:
                file.write(',\n')
            json.dump(data, file)
            first = False

    file.write(']') # Kết thúc một json array
# Out:
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tay-ho-ha-noi/116752347.htm#px=SR-stickyad-[PO-1][PL-top]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-10-tp-ho-chi-minh/117346827.htm#px=SR-stickyad-[PO-2][PL-top]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-binh-thanh-tp-ho-chi-minh/116102360.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thu-duc-tp-ho-chi-minh/117516442.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-nha-trang-khanh-hoa/116739355.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-nam-tu-liem-ha-noi/117344266.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-binh-tp-ho-chi-minh/114629007.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-bac-tu-liem-ha-noi/117252191.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-12-tp-ho-chi-minh/114332575.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/114741137.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-11-tp-ho-chi-minh/116696913.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-binh-thanh-tp-ho-chi-minh/116651758.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-di-an-binh-duong/117363059.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-huyen-hoai-duc-ha-noi/117516063.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-bac-tu-liem-ha-noi/117516040.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-di-an-binh-duong/116481448.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-di-an-binh-duong/115975089.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-binh-thanh-tp-ho-chi-minh/112979346.htm#px=SR-special_display_ad-[PO-18][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-binh-tp-ho-chi-minh/116777636.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-thanh-xuan-ha-noi/117393297.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-nam-tu-liem-ha-noi/115036595.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/117117117.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-nam-tu-liem-ha-noi/116918651.htm#px=SR-stickyad-[PO-1][PL-top]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-son-tra-da-nang/116312278.htm#px=SR-stickyad-[PO-2][PL-top]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-ba-dinh-ha-noi/116948752.htm#px=SR-stickyad-[PO-3][PL-top]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-huyen-go-dau-tay-ninh/117346347.htm#px=SR-stickyad-[PO-4][PL-top]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thu-duc-tp-ho-chi-minh/114527801.htm#px=SR-stickyad-[PO-5][PL-top]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-cau-giay-ha-noi/117515833.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thu-duc-tp-ho-chi-minh/114443916.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thu-duc-tp-ho-chi-minh/117250639.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-5-tp-ho-chi-minh/117515704.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-vung-tau-ba-ria-vung-tau/117133969.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-vung-tau-ba-ria-vung-tau/114924884.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-8-tp-ho-chi-minh/117148545.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/116983279.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-huyen-binh-chanh-tp-ho-chi-minh/114696840.htm#px=SR-special_display_ad-[PO-14][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-binh-tan-tp-ho-chi-minh/117123642.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-binh-tan-tp-ho-chi-minh/114995749.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/113658652.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-thanh-xuan-ha-noi/117421960.htm#px=SR-special_display_ad-[PO-18][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-binh-tan-tp-ho-chi-minh/117481721.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thanh-hoa-thanh-hoa/117515107.htm#px=SR-special_display_ad-[PO-20][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-binh-tan-tp-ho-chi-minh/91239571.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thu-duc-tp-ho-chi-minh/116971400.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-huyen-thanh-tri-ha-noi/117515100.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-di-an-binh-duong/117339110.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-di-an-binh-duong/117515077.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/111897434.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-bac-tu-liem-ha-noi/117515055.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/117515028.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-binh-tan-tp-ho-chi-minh/117515027.htm#px=SR-special_display_ad-[PO-4][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-4-tp-ho-chi-minh/117157158.htm#px=SR-special_display_ad-[PO-5][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-ba-dinh-ha-noi/116948752.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/117514925.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-cau-giay-ha-noi/117514894.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thu-duc-tp-ho-chi-minh/117120917.htm#px=SR-special_display_ad-[PO-9][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thu-duc-tp-ho-chi-minh/115501725.htm#px=SR-special_display_ad-[PO-10][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thu-duc-tp-ho-chi-minh/115507671.htm#px=SR-special_display_ad-[PO-11][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-ngu-hanh-son-da-nang/115854242.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-5-tp-ho-chi-minh/113766854.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-di-an-binh-duong/116709497.htm#px=SR-special_display_ad-[PO-14][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-binh-tan-tp-ho-chi-minh/116707515.htm#px=SR-special_display_ad-[PO-15][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-nha-trang-khanh-hoa/116713080.htm#px=SR-special_display_ad-[PO-16][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/116370209.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-ha-dong-ha-noi/117514609.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/116876000.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-11-tp-ho-chi-minh/117514424.htm#px=SR-special_display_ad-[PO-20][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thuan-an-binh-duong/115523299.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-son-tra-da-nang/117263557.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/117514341.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-ha-dong-ha-noi/117514325.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-bien-hoa-dong-nai/116505366.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-bien-hoa-dong-nai/116449037.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/113562591.htm#px=SR-special_display_ad-[PO-7][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/117074438.htm#px=SR-special_display_ad-[PO-8][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/117440866.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/117514273.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thu-duc-tp-ho-chi-minh/114815331.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thu-duc-tp-ho-chi-minh/115398791.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-6-tp-ho-chi-minh/114761663.htm#px=SR-special_display_ad-[PO-13][PL-default]
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/117514082.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-5-tp-ho-chi-minh/116643868.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-thanh-pho-thu-duc-tp-ho-chi-minh/116194660.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-binh-tan-tp-ho-chi-minh/117513763.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/117513750.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-10-tp-ho-chi-minh/116749933.htm
# https://www.nhatot.com//mua-ban-can-ho-chung-cu-quan-tan-phu-tp-ho-chi-minh/117513697.htm

# %% [markdown]
# # Đọc từ file Json

# %%
with open('../../data/test/res.json', 'r') as file:
    json_data = json.load(file)

df_items = pd.json_normalize(json_data)
df_items
# Out:
#                                                DiaChi TinhTrangBatDongSan  \
# 0    Võ Chí Công, Phường Xuân La, Quận Tây Hồ, Hà Nội         Đã bàn giao
# 1   258, Đường Lý Thường Kiệt, Phường 14, Quận 10,...       Chưa bàn giao
# 2   482A, Đường Nơ Trang Long, Phường 13, Quận Bìn...         Đã bàn giao
# 3   Nguyễn Thị Định, Phường Cát Lái (Quận 2 cũ), T...         Đã bàn giao
# 4   Phạm Văn Đồng, Phường Vĩnh Hòa, Thành phố Nha ...       Chưa bàn giao
# ..                                                ...                 ...
# 82  Thạnh Mỹ Lợi, Phường Thạnh Mỹ Lợi (Quận 2 cũ),...         Đã bàn giao
# 83  Trương Phước Phan, Phường Bình Trị Đông, Quận ...         Đã bàn giao
# 84  Trịnh Đình Trọng, Phường Hòa Thạnh, Quận Tân P...         Đã bàn giao
# 85  Đường Thành Thái, Phường 14, Quận 10, Thành ph...       Chưa bàn giao
# 86  Nguyễn Sơn, Phường Phú Thạnh, Quận Tân Phú, Tp...         Đã bàn giao
#
#    DienTich          Gia/M2 SoPhongNgu SoPhongVeSinh LoaiHinhCanHo  \
# 0     52 m²  20,19 triệu/m²    2 phòng       1 phòng      Chung cư
# 1     80 m²     85 triệu/m²    2 phòng       2 phòng      Chung cư
# 2   62.2 m²  38,59 triệu/m²    2 phòng       1 phòng      Chung cư
# 3   58.5 m²  33,85 triệu/m²    2 phòng       2 phòng      Chung cư
# 4     30 m²     40 triệu/m²    1 phòng       1 phòng      Chung cư
# ..      ...             ...        ...           ...           ...
# 82    84 m²  58,21 triệu/m²    2 phòng       2 phòng      Chung cư
# 83    85 m²  34,12 triệu/m²    3 phòng       2 phòng      Chung cư
# 84   105 m²   41,9 triệu/m²    3 phòng       2 phòng      Chung cư
# 85    92 m²  43,48 triệu/m²    3 phòng       2 phòng      Chung cư
# 86    45 m²  29,33 triệu/m²    1 phòng           NaN      Chung cư
#
#         GiayToPhapLy  TinhTrangNoiThat HuongCuaChinh TenPhanKhu/Lo/Block/Thap  \
# 0      Sổ hồng riêng   Nội thất đầy đủ           NaN                      NaN
# 1      Sổ hồng riêng   Nội thất đầy đủ      Đông Nam                        C
# 2      Sổ hồng riêng   Nội thất đầy đủ           Tây                      NaN
# 3   Hợp đồng mua bán   Nội thất đầy đủ       Tây Bắc                      NaN
# 4      Sổ hồng riêng  Nội thất cao cấp       Tây Nam                      NaN
# ..               ...               ...           ...                      ...
# 82     Sổ hồng riêng  Nội thất cao cấp       Tây Nam                        B
# 83     Sổ hồng riêng   Nội thất đầy đủ           NaN                      NaN
# 84     Sổ hồng riêng               NaN           NaN                      NaN
# 85     Sổ hồng riêng   Nội thất đầy đủ           Tây                      NaN
# 86  Hợp đồng mua bán               NaN           NaN                      NaN
#
#    TangSo HuongBanCong DacDiemCanHo MaCan
# 0     NaN          NaN          NaN   NaN
# 1      12          Bắc          NaN   NaN
# 2       2          NaN          NaN   NaN
# 3     NaN     Đông Nam          NaN   NaN
# 4     NaN     Đông Bắc          NaN   NaN
# ..    ...          ...          ...   ...
# 82    NaN     Đông Nam          NaN   NaN
# 83    NaN          NaN          NaN   NaN
# 84    NaN          NaN          NaN   NaN
# 85    NaN         Đông          NaN   NaN
# 86    NaN          NaN          NaN   NaN
#
# [87 rows x 15 columns]
